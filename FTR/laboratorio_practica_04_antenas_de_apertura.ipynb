# %% [markdown]
# # Práctica 04: Antenas de apertura

# %%
# Esto se emplea para que la salida se adapte al formato del notebook a partir de notebook 7 se usa ipympl en vez de notebook
# %matplotlib ipympl

import numpy as np  # cálculo numérico
import matplotlib.pyplot as plt  # gráficos
import matplotlib.transforms as mtransforms
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import matplotlib.colors as mcolors
import scipy.special as sc
import sympy as sp
from sympy.vector import CoordSys3D # para trabajar con vectores
N = CoordSys3D('N') # Sistema de coordenadas de referencia 
# (los vectores unitarios para x,y,z son N.i,N.j,N.k)
from sympy import fourier_transform

# %% [markdown]
# ## Corrientes equivalentes en la apertura para incidencia frontal

# %% [markdown]
# Esta apertura cuadrada se usará como base para los siguientes ejercicios.
# El campo incidente con fasores de campo eléctrico $E_i$ y magnético $H_i$
# corresponde a una onda plana que se propaga desde z<0 hacia z>0 a
# través de la apertura realizada en un plano conductor perfecto. La
# onda plana incidente tiene vector de propagación
# $\vec{\rm{\beta}}$. Cuando $\vec{\rm{\beta}}$ es paralelo a
# $\hat{\mathbf{z}}$ diremos que la incidencia es frontal, con el frente
# de ondas coplanar con la apertura. Con incidencia oblicua la dirección
# de llegada de la onda plana puede tener una inclinación arbitraria
# $(\theta,\phi)$.
#
# <img src="figuras/apertura_xy.svg" alt="apertura" class="bg-primary mb-1" width="500px">

# %% [markdown]
# Lo primero que tenemos que hacer es calcular las corrientes
# equivalentes en la superficie de la apertura en la condiciones
# siguientes:
#
# - Incidencia frontal, asumimos iluminación uniforme en la apertura,
#   como si los campos no fueran perturbados por la apertura
# - El campo eléctrico en la apertura será por tanto constante e igual a
#   $E_0 \hat{\mathbf{x}}$
# - Los vectores unitarios
#   $\hat{\mathbf{x}},\hat{\mathbf{y}},\hat{\mathbf{z}}$ son N.i,N.j,N.k
#   y se muestran en el dibujo de la apertura
# - Recordad que en sympy el producto vectorial se puede representar
#   mediante el símbolo ^
# - Versión del teorema de equivalencia: rellenando con PEC y aplicando
#   imágenes

# %%
def respuesta_01():
    # M_ss Densidad de corriente magnética superficial
    # Símbolos a utilizar, no hacen falta todos
    E_0, H_0, a, k_x, k_y, k_z, x, y, z=sp.symbols('E_0 H_0 a k_x k_y k_z x y z') 
    # Edita a partir de aquí
    π = sp.pi
    
    M_ss=2*(-N.k^N.i*E_0) #multiplico por dos al ser rellenando con PEC y aplicando imágenes

    #M_ss=2*(-N.k^N.i*(E_0*sp.cos(sp.pi*y/a))) no es ya que la iluminación es uniforme en la apertura
    
    return M_ss

respuesta_01()
# Out:
# (-2*E_0)*N.j

# %% [markdown]
# ## Diagrama normalizado de apertura cuadrada con iluminación frontal

# %% [markdown]
# Se parte de la apertura del dibujo anterior. Asumimos apertura
# cuadrada de lado 3 longitudes de onda. Tenemos iluminación frontal, es
# decir el frente de onda de la onda plana incidente es coplanar con la
# apertura. Se desea representar el diagrama de radiación normalizado,
# empleando [dB] y mostrando valores de 0 a -30 dB de atenuación

# %%
def respuesta_02():
    # El objetivo de esta función es devolver 4 matrices con 
    # la superficie mallada para alimentar plot_surface:
    # X la matriz de coordenadas X de los parches a representar
    # Y la matriz de coordenadas Y de los parches a representar
    # Z la matriz de coordenadas Z de los parches a representar
    # R_log la distancia de cada punto de la malla al origen 
    # (para colorear cada parche en consecuencia)
    # Representamos únicamente en x>0, 70 segmentos en theta y
    # 140 segmentos en phi

    from numpy import sin,cos,sinc,pi
    π=pi
    # Editar a partir de aquí
    t = np.linspace(0, np.pi/2, 71)  
    p = np.linspace(0, 2*pi, 141)
    θ,φ = np.meshgrid(t,p)

    k = 2*np.pi
    kx = k*np.sin(θ)*np.cos(φ)
    ky = k*np.sin(θ)*np.sin(φ)
    kz = k*np.cos(θ)
    l=3

    V = np.sinc(kx*l/k)*np.sinc(ky*l/k)
    Vtheta = V*np.cos(θ)*np.sin(φ)
    Vphi = V*np.cos(φ)
    Vrad = 0
   
    Diagrama_De_Radiacion = np.abs(Vphi**2+Vtheta**2)
    D_Normalizado = Diagrama_De_Radiacion / np.max(Diagrama_De_Radiacion)

    
    R_log = 10*np.log10(D_Normalizado)
    R_log[R_log <-30] = -30
    R_log = R_log + 30
    X = R_log*np.sin(θ)*np.cos(φ)
    Y = R_log*np.sin(θ)*np.sin(φ)
    Z = R_log*np.cos(θ)

    

    
    return X,Y,Z,R_log

from ftrlearn04 import muestra_diagrama3d, muestra_vista
muestra_diagrama3d(muestra_vista,X=respuesta_02()[0],Y=respuesta_02()[1],Z=respuesta_02()[2],R_log=respuesta_02()[3])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Alimentación uniforme de la apertura, fase progresiva debida a incidencia oblicua

# %% [markdown]
# Suponemos ahora que el vector de propagación de la onda plana
# incidente está contenido en el plano XZ. En el origen de coordenadas
# está dirigido hacia la dirección $(\theta=2\pi/6,\phi=0)$. La onda
# incidente viene desde las coordenadas z negativas hacia la
# apertura. La longitud de onda es 0,3 [m]. Aproximamos el campo
# incidente en la apertura por el campo que existiría en esa superficie
# en espacio libre, sin colocar la apertura.

# %% [markdown]
# El objetivo ahora consiste en expresar la fase en radianes en cada
# punto de la superficie de la apertura. Tomamos como referencia una
# fase nula en el centro de la apertura en (x=0,y=0,z=0).

# %%
def respuesta_03():   
    # fase: esta función devuelve la fase en radianes evaluada en una muestreo de puntos
    # de la apertura
    
    # Establecemos el muestreo en (x,y,z=0) de los puntos de la apertura
    x = np.linspace(-0.3*1.5,0.3*1.5, 51)
    y = np.linspace(-0.3*1.5,0.3*1.5, 51)
    z = np.linspace(-0.3*1.5,0.3*1.5, 51)
    from numpy import cos,sin,sinc,exp
    Y,X=np.meshgrid(y,x)
    # Edita a partir de aquí
    θ = 2*np.pi/6
    φ = 0
    k = 2*np.pi
    l = 0.3
    fase = -k/l*(Y*np.sin(θ)*np.sin(φ)+X*np.sin(θ) * np.cos(φ))
    
    return fase

# Para mostrar vuestra respuesta visualmente ejecutad la celda siguiente

# %%
from ftrlearn04 import muestra_respuesta_03
muestra_respuesta_03(respuesta_03())
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Apertura cuadrada con incidencia oblicua estática

# %% [markdown]
# Como en la pregunta anterior el vector de propagación de la onda
# incidente está contenido en el plano XZ.

# %% [markdown]
# En el origen apunta en la dirección $(\theta=\pi/8,\phi=0)$. Se desea
# representar el diagrama de radiación normalizado, empleando [dB] y
# mostrando valores de 0 a -30 dB de atenuación

# %%
def respuesta_04():
    # El objetivo de esta función es devolver cuatro matrices
    # que describen la superficie mallada para plot_surface:
    # X la matriz de coordenadas X de los parches a representar
    # Y la matriz de coordenadas Y de los parches a representar
    # Z la matriz de coordenadas Z de los parches a representar
    # R_log la distancia de cada punto de la malla al origen 
    # (para colorear cada parche en consecuencia)
    from numpy import sin,cos,sinc,pi
    π=pi
    t = np.linspace(0,π/2, 41)
    p = np.linspace(0, 2*π, 74)
    # Hacemos mallado de puntos theta y phi
    #Hacemos mallado de puntos theta y phi
    θ,φ = np.meshgrid(t,p)   

    # Editar a partir de aquí
    theta = 2*np.pi/8
    phi = 0
    l = 3
    k = 2*np.pi
    #falta escribir las k
    kx=0
    ky=0
    V = np.sinc(kx*l/k)*np.sinc(ky*l/k)
    
    Vtheta = V*np.cos(θ)*np.sin(φ)
    Vphi = V*np.cos(φ)
    Vrad = 0


    
    
    #Pasamos theta y phi a cartesianas(obtenemos todos los puntos para las mallas)
    Diagrama_De_Radiacion = np.abs(Vphi**2+Vtheta**2)
    D_Normalizado = Diagrama_De_Radiacion / np.max(Diagrama_De_Radiacion)

    
    R_log = 10*np.log10(D_Normalizado)
    R_log[R_log <-30] = -30
    R_log = R_log + 30
    X = R_log*np.sin(θ)*np.cos(φ)
    Y = R_log*np.sin(θ)*np.sin(φ)
    Z = R_log*np.cos(θ)

    
    return X,Y,Z,R_log

from ftrlearn04 import muestra_diagrama3d, muestra_vista
muestra_diagrama3d(muestra_vista,X=respuesta_04()[0],Y=respuesta_04()[1],Z=respuesta_04()[2],R_log=respuesta_04()[3])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Antena parabólica

# %% [markdown]
# Un paraboloide de revolución se alimenta en el foco con una
# antena de diagrama de radiación
# \begin{eqnarray}
# D(\theta,\phi)= \left\{ {\begin{array}{*{20}lcl}
#    6\cos^2(\theta) & & 0\leq \theta\leq \frac{\pi}{2} \\
#    0 & & \theta>\frac{\pi}{2}  \\
#  \end{array} } \right.
# \end{eqnarray}
#
# - Calcular la eficiencia de desbordamiento en función de $\beta$ (para el intervalo $30°\leq\beta\leq
# 90°)$

# %%
def respuesta_05():
    β = np.arange(30, 90,0.1) 
    from numpy import cos,sin,tan
    # Edita a partir de aquí
          
    neta_s=1-np.cos(np.radians(β))**3
    
    return neta_s   

respuesta_05()
# Out:
# array([0.35048095, 0.35244543, 0.35441184, 0.35638017, 0.35835035,
#        0.36032237, 0.36229617, 0.36427172, 0.36624899, 0.36822793,
#        0.37020851, 0.37219069, 0.37417443, 0.3761597 , 0.37814645,
#        0.38013465, 0.38212426, 0.38411524, 0.38610756, 0.38810117,
#        0.39009604, 0.39209214, 0.39408941, 0.39608783, 0.39808736,
#        0.40008796, 0.4020896 , 0.40409222, 0.4060958 , 0.40810031,
#        0.41010569, 0.41211192, 0.41411895, 0.41612675, 0.41813529,
#        0.42014451, 0.4221544 , 0.4241649 , 0.42617598, 0.42818761,
#        0.43019974, 0.43221235, 0.43422538, 0.43623881, 0.43825259,
#        0.4402667 , 0.44228109, 0.44429572, 0.44631056, 0.44832558,
#        0.45034073, 0.45235597, 0.45437128, 0.45638661, 0.45840193,
#        0.4604172 , 0.46243238, 0.46444744, 0.46646233, 0.46847703,
#        0.4704915 , 0.4725057 , 0.47451959, 0.47653314, 0.47854631,
#        0.48055907, 0.48257137, 0.48458319, 0.48659448, 0.48860522,
#        0.49061535, 0.49262486, 0.4946337 , 0.49664184, 0.49864923,
#        0.50065585, 0.50266166, 0.50466663, 0.50667071, 0.50867388,
#        0.5106761 , 0.51267732, 0.51467753, 0.51667668, 0.51867473,
#        0.52067166, 0.52266742, 0.52466199, 0.52665532, 0.52864739,
#        0.53063815, 0.53262758, 0.53461564, 0.5366023 , 0.53858751,
#        0.54057125, 0.54255349, 0.54453418, 0.5465133 , 0.5484908 ,
#        0.55046667, 0.55244086, 0.55441333, 0.55638407, 0.55835302,
#        0.56032017, 0.56228547, 0.56424889, 0.56621041, 0.56816998,
#        0.57012757, 0.57208316, 0.57403671, 0.57598818, 0.57793754,
#        0.57988477, 0.58182982, 0.58377268, 0.58571329, 0.58765164,
#        0.58958769, 0.59152141, 0.59345277, 0.59538174, 0.59730827,
#        0.59923235, 0.60115395, 0.60307302, 0.60498955, 0.60690349,
#        0.60881482, 0.61072351, 0.61262953, 0.61453284, 0.61643342,
#        0.61833123, 0.62022625, 0.62211845, 0.6240078 , 0.62589425,
#        0.6277778 , 0.62965841, 0.63153604, 0.63341067, 0.63528227,
#        0.63715081, 0.63901626, 0.64087859, 0.64273778, 0.6445938 ,
#        0.64644661, 0.64829619, 0.65014251, 0.65198555, 0.65382527,
#        0.65566164, 0.65749465, 0.65932426, 0.66115044, 0.66297318,
#        0.66479243, 0.66660817, 0.66842039, 0.67022904, 0.67203411,
#        0.67383556, 0.67563337, 0.67742752, 0.67921798, 0.68100472,
#        0.68278772, 0.68456695, 0.68634239, 0.688114  , 0.68988178,
#        0.69164568, 0.69340569, 0.69516178, 0.69691393, 0.69866211,
#        0.70040629, 0.70214647, 0.7038826 , 0.70561466, 0.70734264,
#        0.70906651, 0.71078624, 0.71250182, 0.71421322, 0.71592041,
#        0.71762337, 0.71932209, 0.72101653, 0.72270668, 0.72439251,
#        0.726074  , 0.72775114, 0.72942389, 0.73109224, 0.73275617,
#        0.73441564, 0.73607065, 0.73772118, 0.73936719, 0.74100868,
#        0.74264561, 0.74427798, 0.74590575, 0.74752892, 0.74914745,
#        0.75076134, 0.75237055, 0.75397508, 0.7555749 , 0.75717   ,
#        0.75876034, 0.76034593, 0.76192673, 0.76350273, 0.76507391,
#        0.76664026, 0.76820175, 0.76975837, 0.77131009, 0.77285691,
#        0.77439881, 0.77593577, 0.77746776, 0.77899479, 0.78051682,
#        0.78203384, 0.78354584, 0.7850528 , 0.7865547 , 0.78805154,
#        0.78954328, 0.79102993, 0.79251146, 0.79398785, 0.7954591 ,
#        0.79692519, 0.7983861 , 0.79984183, 0.80129235, 0.80273765,
#        0.80417772, 0.80561254, 0.80704211, 0.8084664 , 0.80988542,
#        0.81129913, 0.81270753, 0.81411061, 0.81550836, 0.81690076,
#        0.8182878 , 0.81966947, 0.82104576, 0.82241666, 0.82378215,
#        0.82514222, 0.82649687, 0.82784608, 0.82918985, 0.83052815,
#        0.83186099, 0.83318835, 0.83451022, 0.83582659, 0.83713746,
#        0.83844281, 0.83974263, 0.84103693, 0.84232567, 0.84360887,
#        0.84488651, 0.84615858, 0.84742507, 0.84868598, 0.8499413 ,
#        0.85119103, 0.85243514, 0.85367364, 0.85490653, 0.85613379,
#        0.85735541, 0.8585714 , 0.85978174, 0.86098643, 0.86218546,
#        0.86337883, 0.86456653, 0.86574856, 0.86692491, 0.86809558,
#        0.86926056, 0.87041985, 0.87157344, 0.87272133, 0.87386352,
#        0.875     , 0.87613077, 0.87725582, 0.87837516, 0.87948877,
#        0.88059666, 0.88169882, 0.88279526, 0.88388596, 0.88497093,
#        0.88605017, 0.88712367, 0.88819143, 0.88925345, 0.89030973,
#        0.89136026, 0.89240506, 0.89344411, 0.89447742, 0.89550498,
#        0.8965268 , 0.89754288, 0.89855321, 0.8995578 , 0.90055665,
#        0.90154976, 0.90253712, 0.90351875, 0.90449464, 0.90546479,
#        0.90642921, 0.9073879 , 0.90834085, 0.90928808, 0.91022959,
#        0.91116537, 0.91209543, 0.91301977, 0.9139384 , 0.91485133,
#        0.91575854, 0.91666005, 0.91755587, 0.91844599, 0.91933041,
#        0.92020916, 0.92108222, 0.92194961, 0.92281132, 0.92366737,
#        0.92451776, 0.92536249, 0.92620158, 0.92703502, 0.92786283,
#        0.928685  , 0.92950155, 0.93031248, 0.93111781, 0.93191753,
#        0.93271165, 0.93350018, 0.93428313, 0.93506051, 0.93583232,
#        0.93659857, 0.93735927, 0.93811444, 0.93886407, 0.93960817,
#        0.94034676, 0.94107984, 0.94180743, 0.94252953, 0.94324615,
#        0.94395731, 0.94466301, 0.94536325, 0.94605807, 0.94674745,
#        0.94743142, 0.94810998, 0.94878315, 0.94945094, 0.95011335,
#        0.9507704 , 0.9514221 , 0.95206847, 0.95270951, 0.95334524,
#        0.95397567, 0.95460081, 0.95522067, 0.95583527, 0.95644463,
#        0.95704874, 0.95764763, 0.95824132, 0.9588298 , 0.95941311,
#        0.95999124, 0.96056422, 0.96113207, 0.96169478, 0.96225239,
#        0.9628049 , 0.96335232, 0.96389469, 0.964432  , 0.96496427,
#        0.96549153, 0.96601378, 0.96653104, 0.96704333, 0.96755066,
#        0.96805305, 0.96855052, 0.96904309, 0.96953076, 0.97001356,
#        0.9704915 , 0.97096461, 0.97143289, 0.97189637, 0.97235506,
#        0.97280899, 0.97325816, 0.9737026 , 0.97414233, 0.97457736,
#        0.97500771, 0.97543341, 0.97585446, 0.9762709 , 0.97668273,
#        0.97708998, 0.97749267, 0.97789082, 0.97828444, 0.97867356,
#        0.97905819, 0.97943836, 0.97981409, 0.98018539, 0.98055229,
#        0.98091481, 0.98127297, 0.98162679, 0.98197629, 0.98232149,
#        0.98266241, 0.98299908, 0.98333152, 0.98365974, 0.98398377,
#        0.98430364, 0.98461936, 0.98493096, 0.98523845, 0.98554187,
#        0.98584123, 0.98613656, 0.98642787, 0.9867152 , 0.98699857,
#        0.98727799, 0.98755349, 0.98782511, 0.98809284, 0.98835674,
#        0.98861681, 0.98887308, 0.98912557, 0.98937432, 0.98961933,
#        0.98986065, 0.99009828, 0.99033227, 0.99056262, 0.99078937,
#        0.99101254, 0.99123216, 0.99144825, 0.99166084, 0.99186995,
#        0.99207561, 0.99227784, 0.99247667, 0.99267212, 0.99286423,
#        0.99305301, 0.9932385 , 0.99342071, 0.99359968, 0.99377544,
#        0.993948  , 0.99411739, 0.99428365, 0.9944468 , 0.99460686,
#        0.99476387, 0.99491784, 0.99506881, 0.99521681, 0.99536186,
#        0.99550399, 0.99564322, 0.99577959, 0.99591312, 0.99604384,
#        0.99617178, 0.99629696, 0.99641942, 0.99653918, 0.99665627,
#        0.99677072, 0.99688255, 0.9969918 , 0.9970985 , 0.99720267,
#        0.99730434, 0.99740353, 0.99750029, 0.99759464, 0.9976866 ,
#        0.99777621, 0.9978635 , 0.99794849, 0.99803121, 0.9981117 ,
#        0.99818998, 0.99826608, 0.99834004, 0.99841187, 0.99848162,
#        0.9985493 , 0.99861496, 0.99867862, 0.99874031, 0.99880006,
#        0.9988579 , 0.99891386, 0.99896798, 0.99902027, 0.99907077,
#        0.99911952, 0.99916654, 0.99921186, 0.99925552, 0.99929754,
#        0.99933795, 0.99937679, 0.99941409, 0.99944987, 0.99948417,
#        0.99951702, 0.99954845, 0.99957848, 0.99960716, 0.99963451,
#        0.99966057, 0.99968536, 0.99970891, 0.99973126, 0.99975244,
#        0.99977248, 0.9997914 , 0.99980925, 0.99982606, 0.99984185,
#        0.99985665, 0.9998705 , 0.99988343, 0.99989547, 0.99990665,
#        0.99991701, 0.99992657, 0.99993537, 0.99994343, 0.9999508 ,
#        0.99995749, 0.99996355, 0.99996901, 0.99997389, 0.99997823,
#        0.99998206, 0.99998542, 0.99998832, 0.99999081, 0.99999292,
#        0.99999468, 0.99999612, 0.99999728, 0.99999818, 0.99999885,
#        0.99999934, 0.99999966, 0.99999986, 0.99999996, 0.99999999])
